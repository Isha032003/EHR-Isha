# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/ehr_mixed_data.csv')

# %%
df.head()
# Out:
#   Patient_ID         Name  Age  Gender Imaging_Type           Image_File  \
# 0      P0001  Priya Mehta   36  Female          MRI         mri_0001.png
# 1      P0002    Raj Singh   59    Male   Ultrasound  ultrasound_0002.png
# 2      P0003   Anil Joshi   59    Male          MRI         mri_0003.png
# 3      P0004  Sneha Mehta   68  Female   Ultrasound  ultrasound_0004.png
# 4      P0005  Ramesh Iyer   35  Female        X-ray       x-ray_0005.png
#
#            Diagnosis ICD10_Code  \
# 0  Diabetes Mellitus      E11.9
# 1       Hypertension        I10
# 2             Asthma      J45.9
# 3             Asthma      J45.9
# 4          Arthritis      M19.9
#
#                                       Clinical_Notes  \
# 0  Complains of discomfort and pain, possible sig...
# 1  Signs of hypertension detected, medication pre...
# 2  Follow-up visit required to monitor asthma pro...
# 3  Follow-up visit required to monitor asthma pro...
# 4  Complains of discomfort and pain, possible sig...
#
#                                   Doctor_Observation  \
# 0  Complains of discomfort and pain, possible sig...
# 1  Signs of hypertension detected, medication pre...
# 2  Follow-up visit required to monitor asthma pro...
# 3  Complains of discomfort and pain, possible sig...
# 4  No severe symptoms but patient reports mild ef...
#
#                                    AI_Generated_Note Report_Date
# 0                                                NaN  2025-03-05
# 1  System identifies hypertension and advises con...  2024-09-25
# 2  AI suggests diagnosis accuracy above 85% for a...  2024-06-14
# 3                                                NaN  2024-10-02
# 4  AI suggests diagnosis accuracy above 85% for a...  2024-05-25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          1000 non-null   object
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   int64
#  3   Gender              1000 non-null   object
#  4   Imaging_Type        1000 non-null   object
#  5   Image_File          1000 non-null   object
#  6   Diagnosis           1000 non-null   object
#  7   ICD10_Code          1000 non-null   object
#  8   Clinical_Notes      1000 non-null   object
#  9   Doctor_Observation  1000 non-null   object
#  10  AI_Generated_Note   701 non-null    object
#  11  Report_Date         1000 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#                Age
# count  1000.000000
# mean     49.682000
# std      18.377339
# min      18.000000
# 25%      33.750000
# 50%      50.000000
# 75%      66.000000
# max      80.000000

# %%
df.isnull().sum()
# Out:
# Patient_ID              0
# Name                    0
# Age                     0
# Gender                  0
# Imaging_Type            0
# Image_File              0
# Diagnosis               0
# ICD10_Code              0
# Clinical_Notes          0
# Doctor_Observation      0
# AI_Generated_Note     299
# Report_Date             0
# dtype: int64

# %%
df['Diagnosis'] = df['Diagnosis'].replace('None', np.nan)

print(df)
# Out:
#     Patient_ID         Name  Age  Gender Imaging_Type           Image_File  \
# 0        P0001  Priya Mehta   36  Female          MRI         mri_0001.png
# 1        P0002    Raj Singh   59    Male   Ultrasound  ultrasound_0002.png
# 2        P0003   Anil Joshi   59    Male          MRI         mri_0003.png
# 3        P0004  Sneha Mehta   68  Female   Ultrasound  ultrasound_0004.png
# 4        P0005  Ramesh Iyer   35  Female        X-ray       x-ray_0005.png
# ..         ...          ...  ...     ...          ...                  ...
# 995      P0996  Meena Joshi   55  Female        X-ray       x-ray_0996.png
# 996      P0997  Sunita Iyer   25    Male           CT          ct_0997.png
# 997      P0998     Raj Iyer   73    Male        X-ray       x-ray_0998.png
# 998      P0999   Manoj Iyer   57  Female          DXA         dxa_0999.png
# 999      P1000   Anil Kumar   73    Male          DXA         dxa_1000.png
#
#              Diagnosis ICD10_Code  \
# 0    Diabetes Mellitus      E11.9
# 1         Hypertension        I10
# 2               Asthma      J45.9
# 3               Asthma      J45.9
# 4            Arthritis      M19.9
# ..                 ...        ...
# 995             Asthma      J45.9
# 996          Arthritis      M19.9
# 997       Hypertension        I10
# 998           Migraine      G43.9
# 999           Migraine      G43.9
#
#                                         Clinical_Notes  \
# 0    Complains of discomfort and pain, possible sig...
# 1    Signs of hypertension detected, medication pre...
# 2    Follow-up visit required to monitor asthma pro...
# 3    Follow-up visit required to monitor asthma pro...
# 4    Complains of discomfort and pain, possible sig...
# ..                                                 ...
# 995  Follow-up visit required to monitor asthma pro...
# 996  Patient shows symptoms consistent with arthrit...
# 997  Signs of hypertension detected, medication pre...
# 998  Follow-up visit required to monitor migraine p...
# 999  Complains of discomfort and pain, possible sig...
#
#                                     Doctor_Observation  \
# 0    Complains of discomfort and pain, possible sig...
# 1    Signs of hypertension detected, medication pre...
# 2    Follow-up visit required to monitor asthma pro...
# 3    Complains of discomfort and pain, possible sig...
# 4    No severe symptoms but patient reports mild ef...
# ..                                                 ...
# 995  Complains of discomfort and pain, possible sig...
# 996  No severe symptoms but patient reports mild ef...
# 997  Follow-up visit required to monitor hypertensi...
# 998  No severe symptoms but patient reports mild ef...
# 999  Follow-up visit required to monitor migraine p...
#
#                                      AI_Generated_Note Report_Date
# 0                                                  NaN  2025-03-05
# 1    System identifies hypertension and advises con...  2024-09-25
# 2    AI suggests diagnosis accuracy above 85% for a...  2024-06-14
# 3                                                  NaN  2024-10-02
# 4    AI suggests diagnosis accuracy above 85% for a...  2024-05-25
# ..                                                 ...         ...
# 995  AI summary: Detected signs of asthma. Recommen...  2025-03-18
# 996  System identifies arthritis and advises contin...  2025-07-18
# 997  AI suggests diagnosis accuracy above 85% for h...  2025-01-07
# 998                                                NaN  2024-09-17
# 999  Automated summary: Migraine noted, clinical no...  2024-09-27
#
# [1000 rows x 12 columns]

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], bins=5, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
corr_matrix = numeric_df.corr()
plt.figure(figsize=(6,5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Final Correlation Heatmap')
plt.show()

# %%
print("\n🔢 Correlation Table:")
print(numeric_df.corr())
# Out:
# 🔢 Correlation Table:
#      Age
# Age  1.0

# %%
df.to_csv("ehr_cleaned_with_bp.csv", index=False)
print("\n💾 Cleaned dataset saved as 'ehr_cleaned_with_bp.csv'")
# Out:
# 💾 Cleaned dataset saved as 'ehr_cleaned_with_bp.csv'

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=df, x='Gender', palette='pastel')
plt.title("Gender Distribution of Patients")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-2758654755.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Gender', palette='pastel')

# %%
print(df.columns)
# Out:
# Index(['Patient_ID', 'Name', 'Age', 'Gender', 'Imaging_Type', 'Image_File',
#        'Diagnosis', 'ICD10_Code', 'Clinical_Notes', 'Doctor_Observation',
#        'AI_Generated_Note', 'Report_Date'],
#       dtype='object')

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Diagnosis', y='Age', data=df)
plt.title('Diagnosis vs Age')
plt.show()

# %%
df['Imaging_Type'].value_counts()
# Out:
# Imaging_Type
# Ultrasound    213
# DXA           210
# CT            207
# X-ray         190
# MRI           180
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Gender', hue='Diagnosis', data=df)
plt.title('Gender vs Diagnosis')
plt.show()

# %%
df['Diagnosis'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(6,6))
plt.title('Diagnosis Distribution')
plt.show()

# %%
sns.pairplot(numeric_df)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(y='Imaging_Type', data=df)
plt.title('Imaging Type Count')
plt.show()

# %%
df['AI_Note_Length'] = df['AI_Generated_Note'].astype(str).apply(len)
plt.figure(figsize=(8,5))
sns.scatterplot(x='Age', y='AI_Note_Length', hue='Diagnosis', data=df)
plt.title('Age vs AI Note Length')
plt.show()

# %%
df['Clinical_Notes_Length'] = df['Clinical_Notes'].astype(str).apply(lambda x: len(x.split()))
plt.figure(figsize=(8,5))
sns.histplot(df['Clinical_Notes_Length'], bins=20, kde=True)
plt.title('Distribution of Clinical Notes Length')
plt.show()

# %%
top_icd = df['ICD10_Code'].value_counts().head(10)
plt.figure(figsize=(8,5))
sns.barplot(x=top_icd.values, y=top_icd.index)
plt.title('Top 10 ICD10 Codes')
plt.show()

# %%
df['Report_Date'] = pd.to_datetime(df['Report_Date'], errors='coerce')
df['Report_Month'] = df['Report_Date'].dt.month
plt.figure(figsize=(8,5))
sns.countplot(x='Report_Month', data=df)
plt.title('Reports per Month')
plt.show()

# %%
import numpy as np
numeric_df = df[['Age', 'AI_Note_Length', 'Clinical_Notes_Length']].copy()

# %%
numeric_df.mean()
numeric_df.median()
numeric_df.std()
numeric_df.min()
numeric_df.max()
# Out:
# Age                      80
# AI_Note_Length           91
# Clinical_Notes_Length    11
# dtype: int64

# %%
corr_matrix = numeric_df.corr()
print(corr_matrix)

# Heatmap visualization
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#                             Age  AI_Note_Length  Clinical_Notes_Length
# Age                    1.000000        0.026998               0.009233
# AI_Note_Length         0.026998        1.000000              -0.026281
# Clinical_Notes_Length  0.009233       -0.026281               1.000000

# %%
#covariance matrix

# %%
cov_matrix = numeric_df.cov()
print(cov_matrix)
# Out:
#                               Age  AI_Note_Length  Clinical_Notes_Length
# Age                    337.726603       16.366132               0.216310
# AI_Note_Length          16.366132     1088.085717              -1.105226
# Clinical_Notes_Length    0.216310       -1.105226               1.625336

# %%
arr = numeric_df.to_numpy()
arr_T = arr.T

# %%
dot_product = np.dot(arr_T, arr)
print(dot_product)
# Out:
# [[2805690 2551970  434089]
#  [2551970 3691773  444602]
#  [ 434089  444602   77889]]

# %%
arr_squared = arr ** 2
arr_sum = np.sum(arr, axis=0)  # sum per column
arr_mean = np.mean(arr, axis=0)

# %%
# Standardization (Z-score)
arr_standardized = (arr - np.mean(arr, axis=0)) / np.std(arr, axis=0)

# Min-Max Normalization
arr_normalized = (arr - np.min(arr, axis=0)) / (np.max(arr, axis=0) - np.min(arr, axis=0))

# %%
# Inverse (if square matrix)
if arr.shape[0] == arr.shape[1]:
    arr_inv = np.linalg.inv(arr)

# Determinant (if square matrix)
if arr.shape[0] == arr.shape[1]:
    arr_det = np.linalg.det(arr)

# Eigenvalues and Eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(np.dot(arr_T, arr))
print("Eigenvalues:", eigenvalues)
# Out:
# Eigenvalues: [5904778.71185635  661794.84536412    8778.44277953]

# %%
# Sum of each column
numeric_df.sum()

# Cumulative sum
numeric_df.cumsum()

# Product of each column
numeric_df.prod()
# Out:
# Age                      0
# AI_Note_Length           0
# Clinical_Notes_Length    0
# dtype: int64

# %%
fig, axs = plt.subplots(2, 2, figsize=(12,10))

# Histogram of Age
sns.histplot(df['Age'], bins=20, kde=True, ax=axs[0,0]).set(title='Age Distribution')

# Boxplot: Age vs Diagnosis
sns.boxplot(x='Diagnosis', y='Age', data=df, ax=axs[0,1]).set(title='Age vs Diagnosis')

# Countplot: Gender vs Diagnosis
sns.countplot(x='Gender', hue='Diagnosis', data=df, ax=axs[1,0]).set(title='Gender vs Diagnosis')

# Correlation heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', ax=axs[1,1]).set(title='Correlation Heatmap')

plt.tight_layout()
plt.show()
